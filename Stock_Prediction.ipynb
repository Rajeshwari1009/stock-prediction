# %%
import pandas as pd
df = pd.read_csv('MSFT.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060396
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062553
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063632
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062014
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060936
# ...          ...         ...         ...         ...         ...         ...
# 9479  2023-10-23  325.470001  332.730011  324.390015  329.320007  329.320007
# 9480  2023-10-24  331.299988  331.839996  327.600006  330.529999  330.529999
# 9481  2023-10-25  345.019989  346.200012  337.619995  340.670013  340.670013
# 9482  2023-10-26  340.540009  341.630005  326.940002  327.890015  327.890015
# 9483  2023-10-27  330.429993  336.720001  328.399994  329.809998  329.809998
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9479    24374700
# 9480    31153600
# 9481    55053800
# 9482    37828500
# 9483    29835200
#
# [9484 rows x 7 columns]

# %%
df = df[['Date','Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9479  2023-10-23  329.320007
# 9480  2023-10-24  330.529999
# 9481  2023-10-25  340.670013
# 9482  2023-10-26  327.890015
# 9483  2023-10-27  329.809998
#
# [9484 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9479    2023-10-23
# 9480    2023-10-24
# 9481    2023-10-25
# 9482    2023-10-26
# 9483    2023-10-27
# Name: Date, Length: 9484, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split =s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object =str_to_datetime('1980-12-12')
datetime_object
# Out:
# datetime.datetime(1980, 12, 12, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9479  2023-10-23  329.320007
# 9480  2023-10-24  330.529999
# 9481  2023-10-25  340.670013
# 9482  2023-10-26  327.890015
# 9483  2023-10-27  329.809998
#
# [9484 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-68-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9479   2023-10-23
# 9480   2023-10-24
# 9481   2023-10-25
# 9482   2023-10-26
# 9483   2023-10-27
# Name: Date, Length: 9484, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-10-23  329.320007
# 2023-10-24  330.529999
# 2023-10-25  340.670013
# 2023-10-26  327.890015
# 2023-10-27  329.809998
#
# [9484 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index,df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '1986-03-18',
                                '2023-10-27',
                                n=3)
windowed_df
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     1986-03-18    0.097222    0.100694    0.102431    0.099826
# 1     1986-03-19    0.100694    0.102431    0.099826    0.098090
# 2     1986-03-20    0.102431    0.099826    0.098090    0.095486
# 3     1986-03-21    0.099826    0.098090    0.095486    0.092882
# 4     1986-03-24    0.098090    0.095486    0.092882    0.090278
# ...          ...         ...         ...         ...         ...
# 9476  2023-10-23  330.109985  331.320007  326.670013  329.320007
# 9477  2023-10-24  331.320007  326.670013  329.320007  330.529999
# 9478  2023-10-25  326.670013  329.320007  330.529999  340.670013
# 9479  2023-10-26  329.320007  330.529999  340.670013  327.890015
# 9480  2023-10-27  330.529999  340.670013  327.890015  329.809998
#
# [9481 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((9481,), (9481, 3, 1), (9481,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 237/237 [==============================] - 6s 8ms/step - loss: 167.5356 - mean_absolute_error: 6.4007 - val_loss: 2655.5127 - val_mean_absolute_error: 41.2670
# Epoch 2/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3818 - mean_absolute_error: 0.3515 - val_loss: 2372.3357 - val_mean_absolute_error: 37.9204
# Epoch 3/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3587 - mean_absolute_error: 0.3530 - val_loss: 2289.5198 - val_mean_absolute_error: 37.0011
# Epoch 4/100
# 237/237 [==============================] - 1s 3ms/step - loss: 0.3414 - mean_absolute_error: 0.3466 - val_loss: 2241.8423 - val_mean_absolute_error: 36.4128
# Epoch 5/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3332 - mean_absolute_error: 0.3396 - val_loss: 2216.1013 - val_mean_absolute_error: 36.1820
# Epoch 6/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.3161 - mean_absolute_error: 0.3276 - val_loss: 2184.7395 - val_mean_absolute_error: 35.7086
# Epoch 7/100
# 237/237 [==============================] - 1s 6ms/step - loss: 0.3452 - mean_absolute_error: 0.3479 - val_loss: 2161.4741 - val_mean_absolute_error: 35.5109
# Epoch 8/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3223 - mean_absolute_error: 0.3302 - val_loss: 2146.7522 - val_mean_absolute_error: 35.3115
# Epoch 9/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3311 - mean_absolute_error: 0.3438 - val_loss: 2157.8040 - val_mean_absolute_error: 35.5202
# Epoch 10/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3546 - mean_absolute_error: 0.3549 - val_loss: 2153.8792 - val_mean_absolute_error: 35.3682
# Epoch 11/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3190 - mean_absolute_error: 0.3304 - val_loss: 2133.5012 - val_mean_absolute_error: 35.2044
# Epoch 12/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3353 - mean_absolute_error: 0.3425 - val_loss: 2122.4548 - val_mean_absolute_error: 35.1013
# Epoch 13/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3152 - mean_absolute_error: 0.3359 - val_loss: 2085.4761 - val_mean_absolute_error: 34.4781
# Epoch 14/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3181 - mean_absolute_error: 0.3336 - val_loss: 2108.0610 - val_mean_absolute_error: 34.8106
# Epoch 15/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3219 - mean_absolute_error: 0.3345 - val_loss: 2108.0942 - val_mean_absolute_error: 34.7074
# Epoch 16/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3560 - mean_absolute_error: 0.3611 - val_loss: 2117.4150 - val_mean_absolute_error: 34.9117
# Epoch 17/100
# 237/237 [==============================] - 1s 3ms/step - loss: 0.3289 - mean_absolute_error: 0.3378 - val_loss: 2122.5439 - val_mean_absolute_error: 34.7913
# Epoch 18/100
# 237/237 [==============================] - 1s 3ms/step - loss: 0.3025 - mean_absolute_error: 0.3216 - val_loss: 2086.1016 - val_mean_absolute_error: 34.4223
# Epoch 19/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3437 - mean_absolute_error: 0.3528 - val_loss: 2105.1643 - val_mean_absolute_error: 34.7215
# Epoch 20/100
# 237/237 [==============================] - 1s 6ms/step - loss: 0.3209 - mean_absolute_error: 0.3356 - val_loss: 2091.0107 - val_mean_absolute_error: 34.3813
# Epoch 21/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.3150 - mean_absolute_error: 0.3281 - val_loss: 2116.7366 - val_mean_absolute_error: 34.7977
# Epoch 22/100
# 237/237 [==============================] - 1s 3ms/step - loss: 0.3137 - mean_absolute_error: 0.3334 - val_loss: 2090.6055 - val_mean_absolute_error: 34.3914
# Epoch 23/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3193 - mean_absolute_error: 0.3316 - val_loss: 2095.6609 - val_mean_absolute_error: 34.4210
# Epoch 24/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3244 - mean_absolute_error: 0.3334 - val_loss: 2118.6006 - val_mean_absolute_error: 34.7979
# Epoch 25/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3216 - mean_absolute_error: 0.3360 - val_loss: 2078.7600 - val_mean_absolute_error: 34.3251
# Epoch 26/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3368 - mean_absolute_error: 0.3480 - val_loss: 2127.7554 - val_mean_absolute_error: 34.7181
# Epoch 27/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3450 - mean_absolute_error: 0.3523 - val_loss: 2101.8875 - val_mean_absolute_error: 34.6407
# Epoch 28/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3455 - mean_absolute_error: 0.3581 - val_loss: 2127.5977 - val_mean_absolute_error: 34.9487
# Epoch 29/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3081 - mean_absolute_error: 0.3230 - val_loss: 2135.6389 - val_mean_absolute_error: 34.8152
# Epoch 30/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3352 - mean_absolute_error: 0.3438 - val_loss: 2153.0828 - val_mean_absolute_error: 35.0929
# Epoch 31/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3060 - mean_absolute_error: 0.3232 - val_loss: 2127.3308 - val_mean_absolute_error: 34.9081
# Epoch 32/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3203 - mean_absolute_error: 0.3386 - val_loss: 2111.1001 - val_mean_absolute_error: 34.6433
# Epoch 33/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.3218 - mean_absolute_error: 0.3372 - val_loss: 2093.2246 - val_mean_absolute_error: 34.3318
# Epoch 34/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.3175 - mean_absolute_error: 0.3315 - val_loss: 2043.5503 - val_mean_absolute_error: 33.9633
# Epoch 35/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.3146 - mean_absolute_error: 0.3337 - val_loss: 2081.7908 - val_mean_absolute_error: 34.3315
# Epoch 36/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3178 - mean_absolute_error: 0.3327 - val_loss: 2098.5947 - val_mean_absolute_error: 34.4835
# Epoch 37/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3305 - mean_absolute_error: 0.3426 - val_loss: 2107.5125 - val_mean_absolute_error: 34.5248
# Epoch 38/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3306 - mean_absolute_error: 0.3409 - val_loss: 2137.1621 - val_mean_absolute_error: 35.1516
# Epoch 39/100
# 237/237 [==============================] - 1s 3ms/step - loss: 0.3205 - mean_absolute_error: 0.3341 - val_loss: 2115.9890 - val_mean_absolute_error: 34.6110
# Epoch 40/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3047 - mean_absolute_error: 0.3238 - val_loss: 2107.4475 - val_mean_absolute_error: 34.6173
# Epoch 41/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3151 - mean_absolute_error: 0.3312 - val_loss: 2112.4365 - val_mean_absolute_error: 34.6574
# Epoch 42/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3186 - mean_absolute_error: 0.3341 - val_loss: 2086.3411 - val_mean_absolute_error: 34.2773
# Epoch 43/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3497 - mean_absolute_error: 0.3557 - val_loss: 2119.2495 - val_mean_absolute_error: 34.7189
# Epoch 44/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3164 - mean_absolute_error: 0.3313 - val_loss: 2066.2808 - val_mean_absolute_error: 34.0846
# Epoch 45/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3128 - mean_absolute_error: 0.3282 - val_loss: 2110.2004 - val_mean_absolute_error: 34.6451
# Epoch 46/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3043 - mean_absolute_error: 0.3186 - val_loss: 2103.2412 - val_mean_absolute_error: 34.6184
# Epoch 47/100
# 237/237 [==============================] - 1s 6ms/step - loss: 0.3045 - mean_absolute_error: 0.3230 - val_loss: 2076.8994 - val_mean_absolute_error: 34.2704
# Epoch 48/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.3203 - mean_absolute_error: 0.3350 - val_loss: 2074.8906 - val_mean_absolute_error: 34.3209
# Epoch 49/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3012 - mean_absolute_error: 0.3206 - val_loss: 2086.3652 - val_mean_absolute_error: 34.4362
# Epoch 50/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3209 - mean_absolute_error: 0.3345 - val_loss: 2066.1838 - val_mean_absolute_error: 34.1667
# Epoch 51/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3244 - mean_absolute_error: 0.3370 - val_loss: 2068.0615 - val_mean_absolute_error: 34.2879
# Epoch 52/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3025 - mean_absolute_error: 0.3188 - val_loss: 2086.8511 - val_mean_absolute_error: 34.4317
# Epoch 53/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3108 - mean_absolute_error: 0.3310 - val_loss: 2087.8735 - val_mean_absolute_error: 34.3416
# Epoch 54/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3110 - mean_absolute_error: 0.3322 - val_loss: 2077.2927 - val_mean_absolute_error: 34.2734
# Epoch 55/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3068 - mean_absolute_error: 0.3232 - val_loss: 2048.6299 - val_mean_absolute_error: 34.0191
# Epoch 56/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.3260 - mean_absolute_error: 0.3390 - val_loss: 2077.7815 - val_mean_absolute_error: 34.2724
# Epoch 57/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3044 - mean_absolute_error: 0.3264 - val_loss: 2074.9905 - val_mean_absolute_error: 34.3144
# Epoch 58/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3253 - mean_absolute_error: 0.3411 - val_loss: 2081.6819 - val_mean_absolute_error: 34.3846
# Epoch 59/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3019 - mean_absolute_error: 0.3218 - val_loss: 2060.2546 - val_mean_absolute_error: 34.1163
# Epoch 60/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.3128 - mean_absolute_error: 0.3286 - val_loss: 2075.0369 - val_mean_absolute_error: 34.3763
# Epoch 61/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.3353 - mean_absolute_error: 0.3387 - val_loss: 2088.4055 - val_mean_absolute_error: 34.5544
# Epoch 62/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3267 - mean_absolute_error: 0.3395 - val_loss: 2102.4583 - val_mean_absolute_error: 34.6676
# Epoch 63/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3081 - mean_absolute_error: 0.3254 - val_loss: 2081.5764 - val_mean_absolute_error: 34.4790
# Epoch 64/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3174 - mean_absolute_error: 0.3298 - val_loss: 2031.5754 - val_mean_absolute_error: 33.7801
# Epoch 65/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3145 - mean_absolute_error: 0.3294 - val_loss: 2018.2275 - val_mean_absolute_error: 33.5610
# Epoch 66/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3160 - mean_absolute_error: 0.3274 - val_loss: 2034.2681 - val_mean_absolute_error: 33.7698
# Epoch 67/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3198 - mean_absolute_error: 0.3322 - val_loss: 2039.4581 - val_mean_absolute_error: 33.9057
# Epoch 68/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3152 - mean_absolute_error: 0.3296 - val_loss: 1990.2257 - val_mean_absolute_error: 33.1575
# Epoch 69/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3143 - mean_absolute_error: 0.3269 - val_loss: 2038.8308 - val_mean_absolute_error: 33.7824
# Epoch 70/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3222 - mean_absolute_error: 0.3355 - val_loss: 2054.9397 - val_mean_absolute_error: 34.0034
# Epoch 71/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3284 - mean_absolute_error: 0.3356 - val_loss: 2026.2007 - val_mean_absolute_error: 33.6293
# Epoch 72/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.2996 - mean_absolute_error: 0.3153 - val_loss: 2045.2998 - val_mean_absolute_error: 33.9866
# Epoch 73/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3018 - mean_absolute_error: 0.3153 - val_loss: 2063.3335 - val_mean_absolute_error: 34.1846
# Epoch 74/100
# 237/237 [==============================] - 1s 6ms/step - loss: 0.3197 - mean_absolute_error: 0.3308 - val_loss: 2077.3738 - val_mean_absolute_error: 34.4914
# Epoch 75/100
# 237/237 [==============================] - 2s 7ms/step - loss: 0.2926 - mean_absolute_error: 0.3077 - val_loss: 2087.8616 - val_mean_absolute_error: 34.4552
# Epoch 76/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.3358 - mean_absolute_error: 0.3450 - val_loss: 2103.3105 - val_mean_absolute_error: 34.7534
# Epoch 77/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3062 - mean_absolute_error: 0.3239 - val_loss: 2052.7739 - val_mean_absolute_error: 33.9415
# Epoch 78/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3042 - mean_absolute_error: 0.3219 - val_loss: 2052.4514 - val_mean_absolute_error: 33.9889
# Epoch 79/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.2935 - mean_absolute_error: 0.3135 - val_loss: 2004.1622 - val_mean_absolute_error: 33.3902
# Epoch 80/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3169 - mean_absolute_error: 0.3269 - val_loss: 2051.1548 - val_mean_absolute_error: 33.9845
# Epoch 81/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3154 - mean_absolute_error: 0.3313 - val_loss: 2030.7600 - val_mean_absolute_error: 33.6882
# Epoch 82/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.2916 - mean_absolute_error: 0.3095 - val_loss: 2008.3833 - val_mean_absolute_error: 33.3217
# Epoch 83/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3093 - mean_absolute_error: 0.3274 - val_loss: 2099.1194 - val_mean_absolute_error: 34.7229
# Epoch 84/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3272 - mean_absolute_error: 0.3376 - val_loss: 2092.9336 - val_mean_absolute_error: 34.5318
# Epoch 85/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3188 - mean_absolute_error: 0.3324 - val_loss: 2117.7305 - val_mean_absolute_error: 34.9802
# Epoch 86/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3171 - mean_absolute_error: 0.3336 - val_loss: 2061.9221 - val_mean_absolute_error: 34.0862
# Epoch 87/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.3208 - mean_absolute_error: 0.3350 - val_loss: 2129.7339 - val_mean_absolute_error: 35.1581
# Epoch 88/100
# 237/237 [==============================] - 1s 5ms/step - loss: 0.2987 - mean_absolute_error: 0.3161 - val_loss: 2011.7104 - val_mean_absolute_error: 33.4196
# Epoch 89/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.2969 - mean_absolute_error: 0.3151 - val_loss: 2013.9099 - val_mean_absolute_error: 33.4356
# Epoch 90/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.2926 - mean_absolute_error: 0.3113 - val_loss: 2014.5055 - val_mean_absolute_error: 33.3614
# Epoch 91/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3127 - mean_absolute_error: 0.3248 - val_loss: 2070.2432 - val_mean_absolute_error: 34.0433
# Epoch 92/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3099 - mean_absolute_error: 0.3258 - val_loss: 2052.0447 - val_mean_absolute_error: 33.9466
# Epoch 93/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.2969 - mean_absolute_error: 0.3148 - val_loss: 2050.3992 - val_mean_absolute_error: 33.8578
# Epoch 94/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.2919 - mean_absolute_error: 0.3098 - val_loss: 2018.6553 - val_mean_absolute_error: 33.4512
# Epoch 95/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3052 - mean_absolute_error: 0.3192 - val_loss: 2067.1211 - val_mean_absolute_error: 34.3185
# Epoch 96/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3162 - mean_absolute_error: 0.3322 - val_loss: 2047.9463 - val_mean_absolute_error: 33.7816
# Epoch 97/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3043 - mean_absolute_error: 0.3176 - val_loss: 2046.2139 - val_mean_absolute_error: 33.7106
# Epoch 98/100
# 237/237 [==============================] - 1s 3ms/step - loss: 0.3155 - mean_absolute_error: 0.3302 - val_loss: 2060.0222 - val_mean_absolute_error: 33.9500
# Epoch 99/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.2975 - mean_absolute_error: 0.3128 - val_loss: 2060.0901 - val_mean_absolute_error: 34.0994
# Epoch 100/100
# 237/237 [==============================] - 1s 4ms/step - loss: 0.3225 - mean_absolute_error: 0.3349 - val_loss: 2073.9065 - val_mean_absolute_error: 34.2912

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 237/237 [==============================] - 1s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 30/30 [==============================] - 0s 2ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 30/30 [==============================] - 0s 2ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
